# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import joblib

import tensorflow as tf
from tensorflow.saved_model import load

from sklearn.metrics import multilabel_confusion_matrix, classification_report
from predictions import single_input_prediction, multi_input_prediction, cal_metrics

# %% [raw]
# Declare Evaluation

# %%
##prefix data
train_prefix_trace_encoded = np.load("dmd_train_prefix.npy")
val_prefix_trace_encoded = np.load("dmd_val_prefix.npy")
test_prefix_trace_encoded = np.load("dmd_test_prefix.npy")

##probability data
train_dfg_probability = pd.read_csv("dmd_train_dfg_probability.csv")
val_dfg_probability = pd.read_csv("dmd_val_dfg_probability.csv")
test_dfg_probability = pd.read_csv("dmd_test_dfg_probability.csv")

#target
train_target_encoded = np.load("dmd_train_target.npy")
val_target_encoded = np.load("dmd_val_target.npy")
test_target_encoded = np.load("dmd_test_target.npy")

#original data
train_target = pd.read_csv("dmd_train_target_org.csv")
test_target = pd.read_csv("dmd_test_target_org.csv")

#encoder
label_encoder = joblib.load('dmd_label_encoder.joblib')
# Out:
# C:\Users\obami\anaconda3\Lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.5.1 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [raw]
# Prefix Model

# %%
prefix_model = tf.keras.models.load_model("dmd_prefix_model.keras")

# %%
#Get labels
predicted_labels = single_input_prediction(prefix_model, test_prefix_trace_encoded, label_encoder)
# Out:
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step

# %%
#actual_label.unique()

# %%
actual_label = test_target["activity"]
report = classification_report(actual_label,predicted_labels,zero_division=np.nan)
print(report)
# Out:
#                                           precision    recall  f1-score   support
#
#   declaration approved by administration       0.89      1.00      0.94      2327
#     declaration approved by budget owner        nan      0.00      0.00       841
# declaration final_approved by supervisor       0.69      1.00      0.82      2242
#   declaration rejected by administration        nan      0.00      0.00       272
#     declaration rejected by budget owner        nan      0.00      0.00        15
#         declaration rejected by employee       0.95      0.77      0.85       341
#       declaration rejected by supervisor        nan      0.00      0.00        70
#            declaration saved by employee        nan      0.00      0.00        24
#        declaration submitted by employee       0.96      1.00      0.98      2601
#                          payment handled       1.00      1.00      1.00      2242
#                          request payment       1.00      1.00      1.00      2236
#                                      zos       1.00      0.95      0.97      2352
#
#                                 accuracy                           0.91     15563
#                                macro avg       0.93      0.56      0.55     15563
#                             weighted avg       0.92      0.91      0.87     15563

# %% [raw]
# DFG Model

# %%
dfg_model = tf.keras.models.load_model("dmd_dfg_model.keras")

# %%
#Get labels
predicted_labels = single_input_prediction(dfg_model, test_dfg_probability, label_encoder)
# Out:
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step

# %%
#get metrics
report = classification_report(actual_label,predicted_labels,zero_division=0)
print(report)
# Out:
#                                           precision    recall  f1-score   support
#
#   declaration approved by administration       0.89      1.00      0.94      2327
#     declaration approved by budget owner       0.00      0.00      0.00       841
# declaration final_approved by supervisor       0.71      1.00      0.83      2242
#   declaration rejected by administration       0.00      0.00      0.00       272
#     declaration rejected by budget owner       0.00      0.00      0.00        15
#         declaration rejected by employee       0.00      0.00      0.00       341
#       declaration rejected by supervisor       0.00      0.00      0.00        70
#            declaration saved by employee       0.00      0.00      0.00        24
#        declaration submitted by employee       0.96      1.00      0.98      2601
#                          payment handled       1.00      1.00      1.00      2242
#                          request payment       0.99      1.00      0.99      2236
#                                      zos       0.87      0.96      0.91      2352
#
#                                 accuracy                           0.89     15563
#                                macro avg       0.45      0.50      0.47     15563
#                             weighted avg       0.81      0.89      0.85     15563

# %% [raw]
# Prefix_DFG Model_1

# %%
prefix_dfg_model = tf.keras.models.load_model("dmd_prefix_dfg_model_1.keras")

# %%
#Get labels
predicted_labels = multi_input_prediction(prefix_dfg_model,test_prefix_trace_encoded, test_dfg_probability, label_encoder)
# Out:
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
#get metrics
report = classification_report(actual_label,predicted_labels,zero_division=0)
print(report)
# Out:
#                                           precision    recall  f1-score   support
#
#   declaration approved by administration       0.88      1.00      0.93      2327
#     declaration approved by budget owner       0.00      0.00      0.00       841
# declaration final_approved by supervisor       0.59      1.00      0.74      2242
#   declaration rejected by administration       0.00      0.00      0.00       272
#     declaration rejected by budget owner       0.00      0.00      0.00        15
#         declaration rejected by employee       0.00      0.00      0.00       341
#       declaration rejected by supervisor       0.00      0.00      0.00        70
#            declaration saved by employee       0.00      0.00      0.00        24
#        declaration submitted by employee       0.99      0.90      0.94      2601
#                          payment handled       1.00      1.00      1.00      2242
#                          request payment       0.99      1.00      1.00      2236
#                                      zos       0.99      0.96      0.98      2352
#
#                                 accuracy                           0.88     15563
#                                macro avg       0.45      0.49      0.47     15563
#                             weighted avg       0.82      0.88      0.84     15563

# %% [raw]
# Prefix_DFG Model_2

# %%
prefix_dfg_model_2 = tf.keras.models.load_model("dmd_prefix_dfg_model_2.keras")

# %%
#Get labels
predicted_labels = multi_input_prediction(prefix_dfg_model_2,test_prefix_trace_encoded, test_dfg_probability, label_encoder)
# Out:
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
#get metrics
report = classification_report(actual_label,predicted_labels,zero_division=0)
print(report)
# Out:
#                                           precision    recall  f1-score   support
#
#   declaration approved by administration       0.89      1.00      0.94      2327
#     declaration approved by budget owner       0.00      0.00      0.00       841
# declaration final_approved by supervisor       0.70      1.00      0.83      2242
#   declaration rejected by administration       0.00      0.00      0.00       272
#     declaration rejected by budget owner       0.00      0.00      0.00        15
#         declaration rejected by employee       0.96      0.89      0.92       341
#       declaration rejected by supervisor       0.00      0.00      0.00        70
#            declaration saved by employee       0.00      0.00      0.00        24
#        declaration submitted by employee       0.96      1.00      0.98      2601
#                          payment handled       0.99      1.00      1.00      2242
#                          request payment       1.00      1.00      1.00      2236
#                                      zos       1.00      0.96      0.98      2352
#
#                                 accuracy                           0.91     15563
#                                macro avg       0.54      0.57      0.55     15563
#                             weighted avg       0.85      0.91      0.88     15563

# %%
#result ["prefix_dfg_2"] = {"macro_accuracy":macro_accuracy,"micro_accuracy":micro_accuracy}

# %% [raw]
# Prefix_DFG Model_3

# %%
prefix_dfg_model_3 = tf.keras.models.load_model("dmd_prefix_dfg_model_3.keras")

# %%
report = classification_report(actual_label,predicted_labels,zero_division=0)
print(report)
# Out:
#                                           precision    recall  f1-score   support
#
#   declaration approved by administration       0.89      1.00      0.94      2327
#     declaration approved by budget owner       0.00      0.00      0.00       841
# declaration final_approved by supervisor       0.70      1.00      0.83      2242
#   declaration rejected by administration       0.00      0.00      0.00       272
#     declaration rejected by budget owner       0.00      0.00      0.00        15
#         declaration rejected by employee       0.96      0.89      0.92       341
#       declaration rejected by supervisor       0.00      0.00      0.00        70
#            declaration saved by employee       0.00      0.00      0.00        24
#        declaration submitted by employee       0.96      1.00      0.98      2601
#                          payment handled       0.99      1.00      1.00      2242
#                          request payment       1.00      1.00      1.00      2236
#                                      zos       1.00      0.96      0.98      2352
#
#                                 accuracy                           0.91     15563
#                                macro avg       0.54      0.57      0.55     15563
#                             weighted avg       0.85      0.91      0.88     15563
